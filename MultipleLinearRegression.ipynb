# %% [markdown]
# <a href="https://colab.research.google.com/github/bhumibansal-ux/Bhumi1/blob/main/MultipleLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
X,y = make_regression(n_samples=200, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.shape
# Out:
# (200, 3)

# %%
df.head()
# Out:
#    feature1  feature2      target
# 0 -0.507918 -1.074289 -144.278266
# 1  1.697968  0.573356   99.995301
# 2  0.578766 -0.342656   31.895855
# 3 -0.521923 -1.062391 -146.611421
# 4  0.277278 -0.255345  146.967191

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="619dffbd-6991-4298-9630-ba5983ed7cee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("619dffbd-6991-4298-9630-ba5983ed7cee")) {                    Plotly.newPlot(                        "619dffbd-6991-4298-9630-ba5983ed7cee",                        [{"hovertemplate":"feature1=%{x}\u003cbr\u003efeature2=%{y}\u003cbr\u003etarget=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[-0.5079180812451715,1.6979681270699298,0.5787660299414952,-0.5219229815133453,0.2772782284617798,-0.550892449764607,0.10371096020286241,-1.040275591448741,-0.14296829301438138,-0.7050842208893451,-2.0833082429854786,1.7681074516547859,1.684972386255965,0.16953223985995572,0.3735385172877785,-2.2352748950613672,0.8218677035949672,-0.9150813653689361,-0.9323850015496509,-0.32511380164006415,2.271629658505704,-1.9583959531013282,0.4990237761964287,0.32089718706688236,1.6383130990624928,1.0277128436069947,0.93489484622161,-0.3411765775965677,0.1920499493612586,-0.33989383357443287,-0.2827722747953329,-1.6880003348383885,0.27289911741197403,-0.4212124920977648,0.8325733697596351,0.42812797169942257,-1.0075681786487034,0.2836278478735254,-0.5353488527602492,-0.2639461621625159,-2.1239392874747915,-0.4439640898746405,0.05255372456675238,-1.7468789600473182,-0.7092481888612503,-2.006670696457659,-0.76661271991619,0.345222698697609,-0.2107610542189094,0.8137993768179602,-1.2167799240382118,0.3714560225981613,-0.16489343929854544,0.8899806106635411,-0.9632138600372451,0.27891784707771394,-0.3983602292734887,-0.2574286745514864,-0.214222882961453,0.6352414608467221,2.5303457967850265,-0.6786185178842244,-0.1882002330559428,-1.1951238862300066,0.6203767570797359,1.1030639053116302,0.5369462440351787,-2.0174407046974467,-0.8396246339254835,-1.126205435934389,0.4486482976434032,1.1328064404598799,-0.06374812570744141,0.1990897686558838,-2.676782122371369,0.4102342237529641,-0.10410085795001502,1.6928363254096794,0.00015674199195275324,0.5680881603031106,-0.3495083012960886,-1.5047694780293617,1.1218015519180597,0.9685923694996592,-1.213090603779271,-0.16772894856429682,-1.032520040596521,-0.39550040321217683,-1.1593588599785511,0.21660213491580557,1.1740347955323962,0.45567701084910717,1.729578762871614,0.736507464686864,-0.9527428176205921,-1.2354447935561839,-0.40460366462875036,0.3282119303569554,-0.32588603958298373,0.5173732806367667,-0.18980583561967088,1.0559957193457197,0.4312296431927526,-0.8869415762732067,0.2608160073278357,0.750769764337837,-1.6327589679549306,0.5728852981724274,-0.8218894253713824,0.2243827813479309,0.6870838991431105,0.6130283014182223,1.5155781324515307,-0.9701026089102918,1.0960230231888162,-1.1787307592881435,1.581562667204293,1.457408437551362,-0.07937743576698374,0.9713566256265584,-0.8436713592531434,1.2369469393794255,-1.1188800669102357,-0.2991149470007821,3.261732629019016,-0.5627283138941536,-0.4659133769135646,0.8410784953868292,1.04728892621148,-0.4821287831488896,-1.693356705117986,-0.6411345745298614,0.21399458281792536,0.5000166551467028,0.36586849336129,1.9558344475837697,1.7208681395210246,-0.06247880771318826,1.1110841600078025,0.5988136058697123,0.7945611581074896,0.6485805687167057,-0.5873558081374247,0.7603566946783795,-0.6143453603908375,0.18299181521727634,1.3547407961385618,-0.421878355732478,2.1246932269977776,-1.0951127047087523,0.17952295351515338,-0.3188297117153984,0.33588880257944836,0.337361866299871,1.3263317456891202,-0.21081116380629042,-1.8265279506627017,0.20726779231263734,0.2125582430470123,-0.7133069861867386,-0.3267031312607389,-0.1636327733112405,-0.875099635695315, ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,df['target'],test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# MAE 41.77760187297362
# MSE 2938.292049390173
# R2 score 0.6677475254984471

# %%
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(y, x)

final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T
z_final = lr.predict(final).reshape(10,10)

z = z_final

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.add_trace(go.Surface(x = x, y = y, z =z ))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="985c77e8-e7d3-42db-840b-37fe5bec810c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("985c77e8-e7d3-42db-840b-37fe5bec810c")) {                    Plotly.newPlot(                        "985c77e8-e7d3-42db-840b-37fe5bec810c",                        [{"hovertemplate":"feature1=%{x}\u003cbr\u003efeature2=%{y}\u003cbr\u003etarget=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[-0.5079180812451715,1.6979681270699298,0.5787660299414952,-0.5219229815133453,0.2772782284617798,-0.550892449764607,0.10371096020286241,-1.040275591448741,-0.14296829301438138,-0.7050842208893451,-2.0833082429854786,1.7681074516547859,1.684972386255965,0.16953223985995572,0.3735385172877785,-2.2352748950613672,0.8218677035949672,-0.9150813653689361,-0.9323850015496509,-0.32511380164006415,2.271629658505704,-1.9583959531013282,0.4990237761964287,0.32089718706688236,1.6383130990624928,1.0277128436069947,0.93489484622161,-0.3411765775965677,0.1920499493612586,-0.33989383357443287,-0.2827722747953329,-1.6880003348383885,0.27289911741197403,-0.4212124920977648,0.8325733697596351,0.42812797169942257,-1.0075681786487034,0.2836278478735254,-0.5353488527602492,-0.2639461621625159,-2.1239392874747915,-0.4439640898746405,0.05255372456675238,-1.7468789600473182,-0.7092481888612503,-2.006670696457659,-0.76661271991619,0.345222698697609,-0.2107610542189094,0.8137993768179602,-1.2167799240382118,0.3714560225981613,-0.16489343929854544,0.8899806106635411,-0.9632138600372451,0.27891784707771394,-0.3983602292734887,-0.2574286745514864,-0.214222882961453,0.6352414608467221,2.5303457967850265,-0.6786185178842244,-0.1882002330559428,-1.1951238862300066,0.6203767570797359,1.1030639053116302,0.5369462440351787,-2.0174407046974467,-0.8396246339254835,-1.126205435934389,0.4486482976434032,1.1328064404598799,-0.06374812570744141,0.1990897686558838,-2.676782122371369,0.4102342237529641,-0.10410085795001502,1.6928363254096794,0.00015674199195275324,0.5680881603031106,-0.3495083012960886,-1.5047694780293617,1.1218015519180597,0.9685923694996592,-1.213090603779271,-0.16772894856429682,-1.032520040596521,-0.39550040321217683,-1.1593588599785511,0.21660213491580557,1.1740347955323962,0.45567701084910717,1.729578762871614,0.736507464686864,-0.9527428176205921,-1.2354447935561839,-0.40460366462875036,0.3282119303569554,-0.32588603958298373,0.5173732806367667,-0.18980583561967088,1.0559957193457197,0.4312296431927526,-0.8869415762732067,0.2608160073278357,0.750769764337837,-1.6327589679549306,0.5728852981724274,-0.8218894253713824,0.2243827813479309,0.6870838991431105,0.6130283014182223,1.5155781324515307,-0.9701026089102918,1.0960230231888162,-1.1787307592881435,1.581562667204293,1.457408437551362,-0.07937743576698374,0.9713566256265584,-0.8436713592531434,1.2369469393794255,-1.1188800669102357,-0.2991149470007821,3.261732629019016,-0.5627283138941536,-0.4659133769135646,0.8410784953868292,1.04728892621148,-0.4821287831488896,-1.693356705117986,-0.6411345745298614,0.21399458281792536,0.5000166551467028,0.36586849336129,1.9558344475837697,1.7208681395210246,-0.06247880771318826,1.1110841600078025,0.5988136058697123,0.7945611581074896,0.6485805687167057,-0.5873558081374247,0.7603566946783795,-0.6143453603908375,0.18299181521727634,1.3547407961385618,-0.421878355732478,2.1246932269977776,-1.0951127047087523,0.17952295351515338,-0.3188297117153984,0.33588880257944836,0.337361866299871,1.3263317456891202,-0.21081116380629042,-1.8265279506627017,0.20726779231263734,0.2125582430470123,-0.7133069861867386,-0.3267031312607389,-0.1636327733112405,-0.875099635695315, ...

# %%
lr.coef_
# Out:
# array([82.33358488, 22.40197245])

# %%
lr.intercept_
# Out:
# np.float64(-2.1443864702798447)
