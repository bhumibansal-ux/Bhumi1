# %% [markdown]
# <a href="https://colab.research.google.com/github/bhumibansal-ux/Bhumi1/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-32b50705-c9a0-4391-860e-3b3c792783c8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32b50705-c9a0-4391-860e-3b3c792783c8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('placement.csv')
print(df.columns)
print(df.head())
# Out:
# Index(['Student Name', 'Branch', 'CGPA', 'Placement ', 'Company', 'Package ',
#        'Internship Experience', 'Skills'],
#       dtype='object')
#    Student Name Branch  CGPA  Placement     Company  Package   \
# 0  Aarav Sharma    CSE   8.9      Placed     Google      25.0
# 1  Bhumi Bansal    CSE   9.2      Placed  Microsoft      22.0
# 2    Riya Verma    ECE   8.1      Placed        TCS       7.0
# 3   Karan Mehta     ME   7.5  Not Placed        NaN       NaN
# 4   Sneha Gupta    CSE   9.0      Placed     Amazon      18.0
#
#   Internship Experience        Skills
# 0                   Yes    Python, ML
# 1                   Yes  DSA, Web Dev
# 2                    No          VLSI
# 3                    No       AutoCAD
# 4                   Yes    AI, Python

# %%
plt.scatter(df['CGPA'], df['Package '])
plt.xlabel('CGPA')
plt.ylabel('Package')
plt.show()

# %%
df_cleaned = df.dropna(subset=['Package '])
X = df_cleaned[['CGPA']]
y = df_cleaned['Package ']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['CGPA'], df['Package '])
plt.plot(X_train, lr.predict(X_train), color='red')
plt.xlabel('CGPA')
plt.ylabel('Package')
plt.show()

# %%
m=lr.coef_
b=lr.intercept_
print("Slope:",m)
print("Intercept:",b)
# Out:
# Slope: [14.00622499]
# Intercept: -109.01534015117832
