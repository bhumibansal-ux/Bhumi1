# %% [markdown]
# <a href="https://colab.research.google.com/github/bhumibansal-ux/Bhumi1/blob/main/multiplelinearregression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
X,y = make_regression(n_samples=200, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.shape
# Out:
# (200, 3)

# %%
df.head()
# Out:
#    feature1  feature2      target
# 0 -1.143179  0.307621  -19.714186
# 1  0.623534 -0.511671   29.499562
# 2  0.387461 -1.159014   15.079622
# 3  1.499306  1.429149  210.289512
# 4 -0.072495  0.972422   36.071614

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ccd5826b-b3bc-4f33-ad36-836337ad02f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ccd5826b-b3bc-4f33-ad36-836337ad02f5")) {                    Plotly.newPlot(                        "ccd5826b-b3bc-4f33-ad36-836337ad02f5",                        [{"hovertemplate":"feature1=%{x}\u003cbr\u003efeature2=%{y}\u003cbr\u003etarget=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[-1.143179399933001,0.6235335235944091,0.38746116290206595,1.4993064854362546,-0.07249460042840432,1.2803081090407435,0.031684328323810663,0.2702467274652763,-0.23600767133691683,-0.7113603579900843,1.4358759289728829,-0.8420462203812422,0.8466100068980342,1.8779457937259882,-0.15197824281380307,-0.3132502939633418,0.11879855853850774,-0.4131617661502337,-1.991329848359364,0.1566847496302702,-0.018928769757270147,-1.9275651323134766,1.6955846928820197,-0.4778956412771666,1.0753550942878862,1.2413640971786408,0.20396885025926648,0.37728782762829416,-0.3708316787845308,-0.5155138480087479,-0.4418808117901934,-1.109408628336461,-1.3608388822603215,-1.292630861961219,0.8550534706250787,1.198858358549403,-1.7295885863016742,-0.6897528841321431,-0.019802506178192836,0.5332765418130728,1.4813985477762903,-0.01891878488442091,-0.29186969749084835,-0.7655894746295818,-0.4319628448843237,-0.8644949038482191,0.23845662338016468,0.13830525209814332,-0.33980033883606253,-0.8622138413020843,-1.472973560489227,-1.076716635295396,1.0812360509861545,-0.8439918171084746,1.2846882932234105,1.2149656097389776,1.032052818559784,0.8414307756101286,0.8660491902383148,0.3305189821789802,0.4067625366486182,0.4638890089121553,0.8430671433674803,0.06939579850582268,1.8161488697005437,-0.5300201724400434,0.9012807076625111,0.019657951338173784,-0.28342838802303305,2.1126708256405675,-0.8767743923288926,0.49146710374378205,-0.10894742674115451,-0.8417089086908071,-0.7955641696677872,-1.1699539240107462,0.1790312502064718,1.3417045838067705,-1.6838270680374343,-0.5558315761729394,0.41375222730585764,-0.6554044292130793,-0.3543965210686303,-1.1784945559208613,-1.7846405245532995,-0.6858360753032184,1.1117886442248879,-0.8032336918548052,0.004511440306236258,0.30169575071394394,0.3928742862582188,0.9193036334971657,-0.3471927150283927,-2.826121754427271,1.3343070384198383,-0.41715964643141357,-1.1613416110950945,0.6522048044397398,-0.9894479107533419,-0.8721221965125167,0.5621227915309845,-0.10045303250553796,0.40254965302388057,-0.31075342236999753,0.8396780344844647,-0.3224302588622849,-0.04651259587554255,0.3026284021605205,-0.7210819736120375,0.8143316146130452,0.33312263681634235,1.1241450444967382,0.18746445453680177,0.1804367004533899,0.8929076225994521,1.3352913054275346,-0.7724091492403838,-0.3236652342044159,-1.2565051842053838,-0.6985971056397233,-0.22980949012553809,-0.8247143109084484,0.2994232800479405,-1.4036984620169324,-0.7536086924517108,-1.0801315775113414,-0.5003952033566932,-1.5071538653167997,-0.8743467158686502,0.9955754822293537,0.5804430972020909,-0.1721570715434478,-0.7541564417850554,-0.24537043501247943,-0.5027657770677444,-2.245619005424916,-0.6863154826561101,0.5425906626311044,0.2654719174379671,-0.3754165546611666,-0.7913118041368442,-1.2805096443079107,0.3346705471798032,0.12351407735686923,1.3679041206764484,1.3467374592814483,1.0134613379647994,1.0628636770515785,0.3843999680589393,1.3339055635092776,-1.8372848950732128,0.09134997568438095,0.6568897446098049,0.15171387240066306,0.476228173786436,-1.7144595657778803,-1.6276383946630884,-0.746085104258236,1.3663227165355494,0.5556472966711766,1.0548043031156036,-1.81464920 ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,df['target'],test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# MAE 37.85136117105061
# MSE 2453.2227525029057
# R2 score 0.44943990164719105

# %%
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(y, x)

final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T
z_final = lr.predict(final).reshape(10,10)

z = z_final

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.add_trace(go.Surface(x = x, y = y, z =z ))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9704b0e0-92ed-422e-815a-a87d9d21be4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9704b0e0-92ed-422e-815a-a87d9d21be4f")) {                    Plotly.newPlot(                        "9704b0e0-92ed-422e-815a-a87d9d21be4f",                        [{"hovertemplate":"feature1=%{x}\u003cbr\u003efeature2=%{y}\u003cbr\u003etarget=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[-1.143179399933001,0.6235335235944091,0.38746116290206595,1.4993064854362546,-0.07249460042840432,1.2803081090407435,0.031684328323810663,0.2702467274652763,-0.23600767133691683,-0.7113603579900843,1.4358759289728829,-0.8420462203812422,0.8466100068980342,1.8779457937259882,-0.15197824281380307,-0.3132502939633418,0.11879855853850774,-0.4131617661502337,-1.991329848359364,0.1566847496302702,-0.018928769757270147,-1.9275651323134766,1.6955846928820197,-0.4778956412771666,1.0753550942878862,1.2413640971786408,0.20396885025926648,0.37728782762829416,-0.3708316787845308,-0.5155138480087479,-0.4418808117901934,-1.109408628336461,-1.3608388822603215,-1.292630861961219,0.8550534706250787,1.198858358549403,-1.7295885863016742,-0.6897528841321431,-0.019802506178192836,0.5332765418130728,1.4813985477762903,-0.01891878488442091,-0.29186969749084835,-0.7655894746295818,-0.4319628448843237,-0.8644949038482191,0.23845662338016468,0.13830525209814332,-0.33980033883606253,-0.8622138413020843,-1.472973560489227,-1.076716635295396,1.0812360509861545,-0.8439918171084746,1.2846882932234105,1.2149656097389776,1.032052818559784,0.8414307756101286,0.8660491902383148,0.3305189821789802,0.4067625366486182,0.4638890089121553,0.8430671433674803,0.06939579850582268,1.8161488697005437,-0.5300201724400434,0.9012807076625111,0.019657951338173784,-0.28342838802303305,2.1126708256405675,-0.8767743923288926,0.49146710374378205,-0.10894742674115451,-0.8417089086908071,-0.7955641696677872,-1.1699539240107462,0.1790312502064718,1.3417045838067705,-1.6838270680374343,-0.5558315761729394,0.41375222730585764,-0.6554044292130793,-0.3543965210686303,-1.1784945559208613,-1.7846405245532995,-0.6858360753032184,1.1117886442248879,-0.8032336918548052,0.004511440306236258,0.30169575071394394,0.3928742862582188,0.9193036334971657,-0.3471927150283927,-2.826121754427271,1.3343070384198383,-0.41715964643141357,-1.1613416110950945,0.6522048044397398,-0.9894479107533419,-0.8721221965125167,0.5621227915309845,-0.10045303250553796,0.40254965302388057,-0.31075342236999753,0.8396780344844647,-0.3224302588622849,-0.04651259587554255,0.3026284021605205,-0.7210819736120375,0.8143316146130452,0.33312263681634235,1.1241450444967382,0.18746445453680177,0.1804367004533899,0.8929076225994521,1.3352913054275346,-0.7724091492403838,-0.3236652342044159,-1.2565051842053838,-0.6985971056397233,-0.22980949012553809,-0.8247143109084484,0.2994232800479405,-1.4036984620169324,-0.7536086924517108,-1.0801315775113414,-0.5003952033566932,-1.5071538653167997,-0.8743467158686502,0.9955754822293537,0.5804430972020909,-0.1721570715434478,-0.7541564417850554,-0.24537043501247943,-0.5027657770677444,-2.245619005424916,-0.6863154826561101,0.5425906626311044,0.2654719174379671,-0.3754165546611666,-0.7913118041368442,-1.2805096443079107,0.3346705471798032,0.12351407735686923,1.3679041206764484,1.3467374592814483,1.0134613379647994,1.0628636770515785,0.3843999680589393,1.3339055635092776,-1.8372848950732128,0.09134997568438095,0.6568897446098049,0.15171387240066306,0.476228173786436,-1.7144595657778803,-1.6276383946630884,-0.746085104258236,1.3663227165355494,0.5556472966711766,1.0548043031156036,-1.81464920 ...

# %%
lr.coef_
# Out:
# array([38.204706  , 44.99369218])

# %%
lr.intercept_
# Out:
# np.float64(6.130265292761978)
